# %% [markdown]
# ### Exercício
# ------------------
# 1. Importe `numpy` como `np`
# 2. Crie um vetor de 20 *uns*
# 3. Crie um vetor de 5 *zeros*
# 4. Crie um vetor de 15 *cincos*
# 5. Crie uma matriz identidade
# 6. Gere a matriz abaixo:
# ![Screen%20Shot%202019-03-17%20at%2023.13.02.png](attachment:Screen%20Shot%202019-03-17%20at%2023.13.02.png)
# 7. Gere uma matriz (4x6) com números de 0 a 23, ordenados do menor para o maior
# 8. Calcule o desvio padrão das colunas da matriz gerada no item (7)
# 9. Calcule a variância das linhas da matriz gerada no item (7)
